# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import os
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress
from datetime import datetime

# Import the OpenWeatherMap API key
from api_keys import weather_api_key


# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "http://api.openweathermap.org/data/2.5/weather?units=metric&appid={}".format(weather_api_key)

# Define an empty list to fetch the weather data for each city
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1 
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
   
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
         # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass  ## general purpose statement to handle all errors and continue

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | khorinsk
# C:\Users\fette00w\AppData\Local\Temp\ipykernel_58780\619683640.py:32: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
# Processing Record 2 of Set 1 | san patricio
# Processing Record 3 of Set 1 | grytviken
# Processing Record 4 of Set 1 | haiku-pauwela
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | mount airy
# Processing Record 7 of Set 1 | fortuna
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | mungwi
# Processing Record 10 of Set 1 | huarmey
# Processing Record 11 of Set 1 | tomatlan
# Processing Record 12 of Set 1 | happy valley-goose bay
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | zilair
# Processing Record 15 of Set 1 | nuevo san juan parangaricutiro
# Processing Record 16 of Set 1 | khandyga
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | argostolion
# Processing Record 19 of Set 1 | puerto natales
# Processing Record 20 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 21 of Set 1 | bamboo flat
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | college
# Processing Record 24 of Set 1 | aberystwyth
# Processing Record 25 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 26 of Set 1 | labuan
# Processing Record 27 of Set 1 | nema
# Processing Record 28 of Set 1 | west island
# Processing Record 29 of Set 1 | wailua homesteads
# Processing Record 30 of Set 1 | san julian
# Processing Record 31 of Set 1 | mykhaylivka
# Processing Record 32 of Set 1 | egilsstadir
# Processing Record 33 of Set 1 | izumi
# Processing Record 34 of Set 1 | aldan
# Processing Record 35 of Set 1 | cao bang
# Processing Record 36 of Set 1 | bouafle
# Processing Record 37 of Set 1 | mvomero
# Processing Record 38 of Set 1 | codrington
# Processing Record 39 of Set 1 | touros
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | olbia
# Processing Record 42 of Set 1 | viqueque
# Processing Record 43 of Set 1 | talnakh
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | bilibino
# Processing Record 46 of Set 1 | mount isa
# Processing Record 47 of Set 1 | manokwari
# Processing Record 48 of Set 1 | morteros
# Processing Record 49 of Set 1 | tazacorte
# Processing Record 50 of Set 1 | invercargill
# Processing Record 0 of Set 2 | flying fish cove
# Processing Record 1 of Set 2 | anadyr
# Processing Record 2 of Set 2 | lihue
# Processing Record 3 of Set 2 | kemijarvi
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | port saint john's
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | edinburgh of the seven seas
# Processing Record 9 of Set 2 | sandnessjoen
# Processing Record 10 of Set 2 | sandpoint
# Processing Record 11 of Set 2 | karratha
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | ascension
# Processing Record 14 of Set 2 | yuzhno-kurilsk
# Processing Record 15 of Set 2 | barentu
# Processing Record 16 of Set 2 | sinabang
# Processing Record 17 of Set 2 | nemuro
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | tazovsky
# Processing Record 20 of Set 2 | kaa-khem
# Processing Record 21 of Set 2 | muisne
# Processing Record 22 of Set 2 | ancud
# Processing Record 23 of Set 2 | udachny
# Processing Record 24 of Set 2 | usinsk
# Processing Record 25 of Set 2 | qaqortoq
# Processing Record 26 of Set 2 | blackmans bay
# Processing Record 27 of Set 2 | natal
# Processing Record 28 of Set 2 | novovarshavka
# Processing Record 29 of Set 2 | acs
# Processing Record 30 of Set 2 | greymouth
# Processing Record 31 of Set 2 | kailua-kona
# Processing Record 32 of Set 2 | enewetak
# Processing Record 33 of Set 2 | olonkinbyen
# Processing Record 34 of Set 2 | ponta pora
# Processing Record 35 of Set 2 | nelson bay
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | cabedelo
# Processing Record 38 of Set 2 | vorgashor
# Processing Record 39 of Set 2 | belmonte
# Processing Record 40 of Set 2 | guines
# Processing Record 41 of Set 2 | wuwei
# Processing Record 42 of Set 2 | saint croix
# Processing Record 43 of Set 2 | port mathurin
# Processing Record 44 of Set 2 | klyuchi
# Processing Record 45 of Set 2 | hamilton
# Processing Record 46 of Set 2 | nar'yan-mar
# Processing Record 47 of Set 2 | vernon
# Processing Record 48 of Set 2 | stanley
# Processing Record 49 of Set 2 | smithers
# Processing Record 0 of Set 3 | sisimiut
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 3 of Set 3 | kastsyukowka
# Processing Record 4 of Set 3 | sormiou
# City not found. Skipping...
# Processing Record 5 of Set 3 | madras
# Processing Record 6 of Set 3 | fort mcmurray
# Processing Record 7 of Set 3 | hawaiian paradise park
# Processing Record 8 of Set 3 | kerikeri
# Processing Record 9 of Set 3 | san andres
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | st. john's
# Processing Record 12 of Set 3 | aras-asan
# Processing Record 13 of Set 3 | papatowai
# Processing Record 14 of Set 3 | abeche
# Processing Record 15 of Set 3 | punta arenas
# Processing Record 16 of Set 3 | tchintabaraden
# Processing Record 17 of Set 3 | bongaigaon
# Processing Record 18 of Set 3 | ilulissat
# Processing Record 19 of Set 3 | tual
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | hermanus
# Processing Record 24 of Set 3 | saint-philippe
# Processing Record 25 of Set 3 | berezovyy
# Processing Record 26 of Set 3 | tura
# Processing Record 27 of Set 3 | mahibadhoo
# Processing Record 28 of Set 3 | kununurra
# Processing Record 29 of Set 3 | siteki
# Processing Record 30 of Set 3 | whitehorse
# Processing Record 31 of Set 3 | port lincoln
# Processing Record 32 of Set 3 | flin flon
# Processing Record 33 of Set 3 | anju
# Processing Record 34 of Set 3 | brookings
# Processing Record 35 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 36 of Set 3 | brokopondo
# Processing Record 37 of Set 3 | beyneu
# Processing Record 38 of Set 3 | mount gambier
# Processing Record 39 of Set 3 | as samawah
# Processing Record 40 of Set 3 | east honolulu
# City not found. Skipping...
# Processing Record 41 of Set 3 | tovuz
# Processing Record 42 of Set 3 | bosobolo
# Processing Record 43 of Set 3 | margaret river
# Processing Record 44 of Set 3 | portland
# Processing Record 45 of Set 3 | adelanto
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | acarau
# Processing Record 48 of Set 3 | salalah
# Processing Record 49 of Set 3 | ursulo galvan
# Processing Record 0 of Set 4 | labrador city
# Processing Record 1 of Set 4 | uvira
# Processing Record 2 of Set 4 | kismayo
# Processing Record 3 of Set 4 | atar
# Processing Record 4 of Set 4 | fauske
# Processing Record 5 of Set 4 | christiansburg
# Processing Record 6 of Set 4 | toliara
# Processing Record 7 of Set 4 | holualoa
# Processing Record 8 of Set 4 | balykshi
# Processing Record 9 of Set 4 | kiunga
# Processing Record 10 of Set 4 | ula
# Processing Record 11 of Set 4 | fale old settlement
# Processing Record 12 of Set 4 | xiaoshi
# Processing Record 13 of Set 4 | natchitoches
# Processing Record 14 of Set 4 | tshabong
# Processing Record 15 of Set 4 | malmberget
# Processing Record 16 of Set 4 | sechura
# Processing Record 17 of Set 4 | peace river
# Processing Record 18 of Set 4 | eaglehawk
# Processing Record 19 of Set 4 | igarka
# Processing Record 20 of Set 4 | hadibu
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | kurumul
# City not found. Skipping...
# Processing Record 23 of Set 4 | nadym
# Processing Record 24 of Set 4 | masterton
# Processing Record 25 of Set 4 | nago
# Processing Record 26 of Set 4 | aasiaat
# Processing Record 27 of Set 4 | thunder bay
# Processing Record 28 of Set 4 | kone
# Processing Record 29 of Set 4 | yellowknife
# Processing Record 30 of Set 4 | mejit
# Processing Record 31 of Set 4 | leh
# Processing Record 32 of Set 4 | gueltat zemmour
# City not found. Skipping...
# Processing Record 33 of Set 4 | kapuskasing
# Processing Record 34 of Set 4 | bhimunipatnam
# Processing Record 35 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 36 of Set 4 | tezu
# Processing Record 37 of Set 4 | strezhevoy
# Processing Record 38 of Set 4 | uturoa
# Processing Record 39 of Set 4 | saldanha
# Processing Record 40 of Set 4 | bambui
# Processing Record 41 of Set 4 | praia da vitoria
# Processing Record 42 of Set 4 | ovalle
# Processing Record 43 of Set 4 | sittwe
# Processing Record 44 of Set 4 | monroe
# Processing Record 45 of Set 4 | mizque
# Processing Record 46 of Set 4 | dryden
# Processing Record 47 of Set 4 | yairipok
# Processing Record 48 of Set 4 | mastic beach
# Processing Record 49 of Set 4 | pionerskiy
# Processing Record 0 of Set 5 | kimberley
# Processing Record 1 of Set 5 | osakarovka
# Processing Record 2 of Set 5 | sibolga
# Processing Record 3 of Set 5 | suntar
# Processing Record 4 of Set 5 | pyt-yakh
# Processing Record 5 of Set 5 | bonthe
# Processing Record 6 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 7 of Set 5 | lagoa
# Processing Record 8 of Set 5 | antalaha
# Processing Record 9 of Set 5 | kuanda
# Processing Record 10 of Set 5 | mirny
# Processing Record 11 of Set 5 | antsiranana
# Processing Record 12 of Set 5 | oshakati
# Processing Record 13 of Set 5 | buala
# Processing Record 14 of Set 5 | phuthaditjhaba
# Processing Record 15 of Set 5 | saipan
# Processing Record 16 of Set 5 | bosaso
# Processing Record 17 of Set 5 | kalifornsky
# Processing Record 18 of Set 5 | goure
# Processing Record 19 of Set 5 | pavlodar
# Processing Record 20 of Set 5 | maposeni
# Processing Record 21 of Set 5 | wanning
# Processing Record 22 of Set 5 | kruisfontein
# Processing Record 23 of Set 5 | atafu village
# Processing Record 24 of Set 5 | pitimbu
# Processing Record 25 of Set 5 | truro
# Processing Record 26 of Set 5 | laminusa
# Processing Record 27 of Set 5 | newman
# Processing Record 28 of Set 5 | iqaluit
# Processing Record 29 of Set 5 | moussoro
# Processing Record 30 of Set 5 | bardai
# Processing Record 31 of Set 5 | krasnyy chikoy
# Processing Record 32 of Set 5 | badger
# Processing Record 33 of Set 5 | stara vyzhivka
# Processing Record 34 of Set 5 | puerto esperanza
# Processing Record 35 of Set 5 | alotau
# Processing Record 36 of Set 5 | fonadhoo
# City not found. Skipping...
# Processing Record 37 of Set 5 | lerwick
# Processing Record 38 of Set 5 | nyrob
# Processing Record 39 of Set 5 | littlefield
# Processing Record 40 of Set 5 | ende
# Processing Record 41 of Set 5 | port-gentil
# Processing Record 42 of Set 5 | novyy urgal
# Processing Record 43 of Set 5 | tsiombe
# Processing Record 44 of Set 5 | quellon
# Processing Record 45 of Set 5 | jamaame
# Processing Record 46 of Set 5 | kargil
# Processing Record 47 of Set 5 | la fria
# Processing Record 48 of Set 5 | ahmadpur east
# Processing Record 49 of Set 5 | utrik
# Processing Record 0 of Set 6 | new norfolk
# Processing Record 1 of Set 6 | songjianghe
# Processing Record 2 of Set 6 | ostersund
# Processing Record 3 of Set 6 | chonchi
# Processing Record 4 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 5 of Set 6 | tofol
# Processing Record 6 of Set 6 | iquitos
# Processing Record 7 of Set 6 | nizhniy kuranakh
# Processing Record 8 of Set 6 | vilyuchinsk
# Processing Record 9 of Set 6 | leava
# Processing Record 10 of Set 6 | nagqu
# Processing Record 11 of Set 6 | tobelo
# Processing Record 12 of Set 6 | zaragoza
# Processing Record 13 of Set 6 | monte carmelo
# Processing Record 14 of Set 6 | lethbridge
# Processing Record 15 of Set 6 | hobyo
# Processing Record 16 of Set 6 | isiro
# Processing Record 17 of Set 6 | kavieng
# Processing Record 18 of Set 6 | nabire
# Processing Record 19 of Set 6 | yelizovo
# Processing Record 20 of Set 6 | iquique
# Processing Record 21 of Set 6 | puerto baquerizo moreno
# Processing Record 22 of Set 6 | thinadhoo
# Processing Record 23 of Set 6 | gizo
# Processing Record 24 of Set 6 | chernyshevskiy
# Processing Record 25 of Set 6 | akonolinga
# Processing Record 26 of Set 6 | kenora
# Processing Record 27 of Set 6 | bafq
# Processing Record 28 of Set 6 | balabac
# Processing Record 29 of Set 6 | say
# Processing Record 30 of Set 6 | yeppoon
# Processing Record 31 of Set 6 | annau
# Processing Record 32 of Set 6 | qoryooley
# Processing Record 33 of Set 6 | sakrand
# Processing Record 34 of Set 6 | kyren
# Processing Record 35 of Set 6 | ta`u
# Processing Record 36 of Set 6 | la passe
# Processing Record 37 of Set 6 | remire-montjoly
# Processing Record 38 of Set 6 | boda
# Processing Record 39 of Set 6 | tijara
# Processing Record 40 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 41 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 42 of Set 6 | dampit
# Processing Record 43 of Set 6 | sitka
# Processing Record 44 of Set 6 | kavaratti
# Processing Record 45 of Set 6 | scone
# Processing Record 46 of Set 6 | libreville
# Processing Record 47 of Set 6 | jackson
# Processing Record 48 of Set 6 | encruzilhada do sul
# Processing Record 49 of Set 6 | kamen'-na-obi
# Processing Record 0 of Set 7 | isle of lewis
# City not found. Skipping...
# Processing Record 1 of Set 7 | misratah
# Processing Record 2 of Set 7 | saudarkrokur
# Processing Record 3 of Set 7 | el daein
# City not found. Skipping...
# Processing Record 4 of Set 7 | tantou
# Processing Record 5 of Set 7 | arraial do cabo
# Processing Record 6 of Set 7 | erdek
# Processing Record 7 of Set 7 | igrim
# Processing Record 8 of Set 7 | aykol
# Processing Record 9 of Set 7 | patnanungan
# Processing Record 10 of Set 7 | north platte
# Processing Record 11 of Set 7 | hithadhoo
# Processing Record 12 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 13 of Set 7 | valentin gomez farias
# Processing Record 14 of Set 7 | al burayqah
# Processing Record 15 of Set 7 | cedartown
# Processing Record 16 of Set 7 | port moresby
# Processing Record 17 of Set 7 | mancio lima
# Processing Record 18 of Set 7 | bougouni
# Processing Record 19 of Set 7 | kodinar
# Processing Record 20 of Set 7 | kearney
# Processing Record 21 of Set 7 | constanta
# Processing Record 22 of Set 7 | ninotsminda
# Processing Record 23 of Set 7 | afaahiti
# Processing Record 24 of Set 7 | cadale
# Processing Record 25 of Set 7 | lock haven
# Processing Record 26 of Set 7 | puerto salgar
# Processing Record 27 of Set 7 | port alfred
# Processing Record 28 of Set 7 | yagry
# City not found. Skipping...
# Processing Record 29 of Set 7 | viedma
# Processing Record 30 of Set 7 | polyarnyy
# Processing Record 31 of Set 7 | malango
# Processing Record 32 of Set 7 | chibougamau
# Processing Record 33 of Set 7 | keflavik
# Processing Record 34 of Set 7 | gamba
# Processing Record 35 of Set 7 | la mira
# Processing Record 36 of Set 7 | kingston
# Processing Record 37 of Set 7 | tobruk
# Processing Record 38 of Set 7 | usogorsk
# Processing Record 39 of Set 7 | howrah
# Processing Record 40 of Set 7 | mega
# Processing Record 41 of Set 7 | san ignacio de velasco
# Processing Record 42 of Set 7 | oliveira dos brejinhos
# Processing Record 43 of Set 7 | callao
# Processing Record 44 of Set 7 | daru
# Processing Record 45 of Set 7 | brovary
# Processing Record 46 of Set 7 | crane
# Processing Record 47 of Set 7 | aykhal
# Processing Record 48 of Set 7 | gaogou
# Processing Record 49 of Set 7 | marsabit
# Processing Record 0 of Set 8 | khomeyni shahr
# Processing Record 1 of Set 8 | geraldton
# Processing Record 2 of Set 8 | san felipe
# Processing Record 3 of Set 8 | at taj
# Processing Record 4 of Set 8 | calama
# Processing Record 5 of Set 8 | panaba
# Processing Record 6 of Set 8 | monte alegre
# Processing Record 7 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 8 of Set 8 | gannan
# Processing Record 9 of Set 8 | campbellton
# Processing Record 10 of Set 8 | duong dong
# Processing Record 11 of Set 8 | ust-nera
# Processing Record 12 of Set 8 | gwanda
# Processing Record 13 of Set 8 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 14 of Set 8 | sanming
# Processing Record 15 of Set 8 | isafjordur
# Processing Record 16 of Set 8 | cam ranh
# Processing Record 17 of Set 8 | mar del plata
# Processing Record 18 of Set 8 | saint-francois
# Processing Record 19 of Set 8 | mandal
# Processing Record 20 of Set 8 | nuuk
# Processing Record 21 of Set 8 | pimenta bueno
# Processing Record 22 of Set 8 | minas de marcona
# Processing Record 23 of Set 8 | west end
# Processing Record 24 of Set 8 | dothan
# Processing Record 25 of Set 8 | shilka
# Processing Record 26 of Set 8 | canutama
# Processing Record 27 of Set 8 | zaozersk
# Processing Record 28 of Set 8 | shasta lake
# Processing Record 29 of Set 8 | capayan
# Processing Record 30 of Set 8 | weno
# Processing Record 31 of Set 8 | wauseon
# Processing Record 32 of Set 8 | isangel
# Processing Record 33 of Set 8 | coxim
# Processing Record 34 of Set 8 | juneau
# Processing Record 35 of Set 8 | anajatuba
# Processing Record 36 of Set 8 | galliano
# Processing Record 37 of Set 8 | priozersk
# Processing Record 38 of Set 8 | lubango
# Processing Record 39 of Set 8 | taesal-li
# Processing Record 40 of Set 8 | puerto ayacucho
# Processing Record 41 of Set 8 | okha
# Processing Record 42 of Set 8 | san antonio de pale
# Processing Record 43 of Set 8 | namibe
# Processing Record 44 of Set 8 | san mariano
# Processing Record 45 of Set 8 | onega
# Processing Record 46 of Set 8 | surab
# Processing Record 47 of Set 8 | jimenez
# Processing Record 48 of Set 8 | esmeraldas
# Processing Record 49 of Set 8 | ust'-ilimsk
# Processing Record 0 of Set 9 | sirte
# Processing Record 1 of Set 9 | borlange
# City not found. Skipping...
# Processing Record 2 of Set 9 | nadvoitsy
# Processing Record 3 of Set 9 | santa terezinha
# Processing Record 4 of Set 9 | carnarvon
# Processing Record 5 of Set 9 | el calafate
# Processing Record 6 of Set 9 | juegang
# Processing Record 7 of Set 9 | rikaze
# Processing Record 8 of Set 9 | bikenibeu village
# Processing Record 9 of Set 9 | taro
# Processing Record 10 of Set 9 | fort bragg
# Processing Record 11 of Set 9 | ola
# Processing Record 12 of Set 9 | santa cruz
# Processing Record 13 of Set 9 | lorengau
# Processing Record 14 of Set 9 | vorkuta
# Processing Record 15 of Set 9 | kill devil hills
# Processing Record 16 of Set 9 | pemangkat
# Processing Record 17 of Set 9 | turaif
# Processing Record 18 of Set 9 | diano marina
# Processing Record 19 of Set 9 | alice springs
# Processing Record 20 of Set 9 | stornoway
# Processing Record 21 of Set 9 | puerto penasco
# Processing Record 22 of Set 9 | ijuw
# City not found. Skipping...
# Processing Record 23 of Set 9 | susuman
# Processing Record 24 of Set 9 | belle fourche
# Processing Record 25 of Set 9 | tolanaro
# Processing Record 26 of Set 9 | nova sintra
# Processing Record 27 of Set 9 | sena madureira
# Processing Record 28 of Set 9 | nieves
# Processing Record 29 of Set 9 | lospalos
# Processing Record 30 of Set 9 | nicoya
# Processing Record 31 of Set 9 | klerksdorp
# Processing Record 32 of Set 9 | turkmenbasy
# Processing Record 33 of Set 9 | piton saint-leu
# Processing Record 34 of Set 9 | lazaro cardenas
# Processing Record 35 of Set 9 | bac lieu
# Processing Record 36 of Set 9 | vilyuysk
# Processing Record 37 of Set 9 | kapit
# Processing Record 38 of Set 9 | borazjan
# Processing Record 39 of Set 9 | cho dok
# Processing Record 40 of Set 9 | nyurba
# Processing Record 41 of Set 9 | galle
# Processing Record 42 of Set 9 | ichinohe
# Processing Record 43 of Set 9 | progreso
# Processing Record 44 of Set 9 | puerto la cruz
# Processing Record 45 of Set 9 | oranjemund
# Processing Record 46 of Set 9 | khorixas
# Processing Record 47 of Set 9 | necochea
# Processing Record 48 of Set 9 | port hueneme
# Processing Record 49 of Set 9 | guia lopes da laguna
# Processing Record 0 of Set 10 | chandbali
# Processing Record 1 of Set 10 | kalengwa
# Processing Record 2 of Set 10 | guayaramerin
# Processing Record 3 of Set 10 | rouyn-noranda
# Processing Record 4 of Set 10 | irymple
# Processing Record 5 of Set 10 | luderitz
# Processing Record 6 of Set 10 | horta
# Processing Record 7 of Set 10 | puerto deseado
# Processing Record 8 of Set 10 | xanthi
# Processing Record 9 of Set 10 | vila velha
# Processing Record 10 of Set 10 | kuala terengganu
# Processing Record 11 of Set 10 | caconda
# Processing Record 12 of Set 10 | inarajan village
# Processing Record 13 of Set 10 | severo-yeniseyskiy
# Processing Record 14 of Set 10 | siwa oasis
# Processing Record 15 of Set 10 | canar
# Processing Record 16 of Set 10 | new plymouth
# Processing Record 17 of Set 10 | yar
# Processing Record 18 of Set 10 | mchinji
# Processing Record 19 of Set 10 | maiwut
# City not found. Skipping...
# Processing Record 20 of Set 10 | pocatello
# Processing Record 21 of Set 10 | dapa
# Processing Record 22 of Set 10 | san luis de la loma
# Processing Record 23 of Set 10 | barda
# Processing Record 24 of Set 10 | marathon
# Processing Record 25 of Set 10 | olgii
# City not found. Skipping...
# Processing Record 26 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 27 of Set 10 | tejen
# Processing Record 28 of Set 10 | christchurch
# Processing Record 29 of Set 10 | pacocha
# Processing Record 30 of Set 10 | tabuk
# Processing Record 31 of Set 10 | sao jose da coroa grande
# Processing Record 32 of Set 10 | as sulayyil
# Processing Record 33 of Set 10 | itabera
# Processing Record 34 of Set 10 | kaya
# Processing Record 35 of Set 10 | rakops
# Processing Record 36 of Set 10 | sinjar
# Processing Record 37 of Set 10 | yashkul'
# Processing Record 38 of Set 10 | soignies
# Processing Record 39 of Set 10 | 'ibri
# City not found. Skipping...
# Processing Record 40 of Set 10 | puerto aysen
# Processing Record 41 of Set 10 | constantia
# Processing Record 42 of Set 10 | port shepstone
# Processing Record 43 of Set 10 | nova vicosa
# Processing Record 44 of Set 10 | alofi
# Processing Record 45 of Set 10 | ulladulla
# Processing Record 46 of Set 10 | raduzhny
# Processing Record 47 of Set 10 | nchelenge
# Processing Record 48 of Set 10 | simanggang
# Processing Record 49 of Set 10 | alta
# Processing Record 0 of Set 11 | kokopo
# Processing Record 1 of Set 11 | fiche
# Processing Record 2 of Set 11 | cidade velha
# Processing Record 3 of Set 11 | meadow lake
# Processing Record 4 of Set 11 | ar ruways
# Processing Record 5 of Set 11 | lagos
# Processing Record 6 of Set 11 | taroa
# Processing Record 7 of Set 11 | neftegorsk
# Processing Record 8 of Set 11 | timbuktu
# Processing Record 9 of Set 11 | hafnarfjordur
# Processing Record 10 of Set 11 | kirakira
# Processing Record 11 of Set 11 | abalak
# Processing Record 12 of Set 11 | katsuren-haebaru
# Processing Record 13 of Set 11 | dudinka
# Processing Record 14 of Set 11 | saint-pierre
# Processing Record 15 of Set 11 | la ronge
# Processing Record 16 of Set 11 | hassi messaoud
# Processing Record 17 of Set 11 | kapa'a
# Processing Record 18 of Set 11 | tralee
# Processing Record 19 of Set 11 | aridaia
# Processing Record 20 of Set 11 | qui nhon
# Processing Record 21 of Set 11 | thanh pho uong bi
# Processing Record 22 of Set 11 | limulunga
# Processing Record 23 of Set 11 | sao joao da barra
# Processing Record 24 of Set 11 | medina
# Processing Record 25 of Set 11 | castanhal
# Processing Record 26 of Set 11 | caleta olivia
# Processing Record 27 of Set 11 | arkhangel'sk
# Processing Record 28 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 29 of Set 11 | kralendijk
# Processing Record 30 of Set 11 | persembe
# Processing Record 31 of Set 11 | bahia blanca
# Processing Record 32 of Set 11 | formosa do rio preto
# Processing Record 33 of Set 11 | amga
# Processing Record 34 of Set 11 | san matias
# Processing Record 35 of Set 11 | szczawnica
# Processing Record 36 of Set 11 | rabaul
# Processing Record 37 of Set 11 | kouango
# Processing Record 38 of Set 11 | chui
# Processing Record 39 of Set 11 | nguigmi
# Processing Record 40 of Set 11 | margate
# Processing Record 41 of Set 11 | gadzhiyevo
# Processing Record 42 of Set 11 | kiama
# Processing Record 43 of Set 11 | mercedes
# Processing Record 44 of Set 11 | gwandu
# Processing Record 45 of Set 11 | badiyah
# Processing Record 46 of Set 11 | sinan
# Processing Record 47 of Set 11 | chimore
# Processing Record 48 of Set 11 | tambura
# Processing Record 49 of Set 11 | mahabe
# City not found. Skipping...
# Processing Record 0 of Set 12 | oualidia
# City not found. Skipping...
# Processing Record 1 of Set 12 | kuytun
# Processing Record 2 of Set 12 | campina
# Processing Record 3 of Set 12 | acapulco de juarez
# Processing Record 4 of Set 12 | clarion
# Processing Record 5 of Set 12 | hammerfest
# Processing Record 6 of Set 12 | abepura
# Processing Record 7 of Set 12 | manggar
# Processing Record 8 of Set 12 | lecheng
# Processing Record 9 of Set 12 | champerico
# Processing Record 10 of Set 12 | bodo
# Processing Record 11 of Set 12 | reggane
# Processing Record 12 of Set 12 | swift current
# Processing Record 13 of Set 12 | nova olimpia
# Processing Record 14 of Set 12 | shimanovsk
# Processing Record 15 of Set 12 | sant pol de mar
# Processing Record 16 of Set 12 | douz
# Processing Record 17 of Set 12 | iskateley
# Processing Record 18 of Set 12 | pacific grove
# Processing Record 19 of Set 12 | las vegas, santa barbara
# Processing Record 20 of Set 12 | powell
# Processing Record 21 of Set 12 | ankazoabo
# Processing Record 22 of Set 12 | maddela
# Processing Record 23 of Set 12 | kristiansund
# Processing Record 24 of Set 12 | znamenskoye
# Processing Record 25 of Set 12 | bandarbeyla
# Processing Record 26 of Set 12 | kuching
# Processing Record 27 of Set 12 | yokadouma
# Processing Record 28 of Set 12 | verkhnevilyuysk
# Processing Record 29 of Set 12 | fort st. john
# Processing Record 30 of Set 12 | chinde
# Processing Record 31 of Set 12 | al kharijah
# Processing Record 32 of Set 12 | celestun
# Processing Record 33 of Set 12 | mahina
# Processing Record 34 of Set 12 | marovoay
# Processing Record 35 of Set 12 | niquero
# Processing Record 36 of Set 12 | merizo village
# Processing Record 37 of Set 12 | santa maria do suacui
# Processing Record 38 of Set 12 | shar
# Processing Record 39 of Set 12 | bollnas
# Processing Record 40 of Set 12 | katsuura
# Processing Record 41 of Set 12 | hajjah
# Processing Record 42 of Set 12 | kupang
# Processing Record 43 of Set 12 | tionk essil
# Processing Record 44 of Set 12 | el alto
# Processing Record 45 of Set 12 | lame
# Processing Record 46 of Set 12 | constitucion
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       khorinsk  52.1657  109.7726    -10.12        98          99
# 1   san patricio  28.0170  -97.5169     22.97        15           0
# 2      grytviken -54.2811  -36.5092      6.86        74          74
# 3  haiku-pauwela  20.9219 -156.3051     24.03        76          75
# 4      adamstown -25.0660 -130.1015     22.95        89           7
#
#    Wind Speed Country                 Date
# 0        0.75      RU  2024-11-21 19:47:59
# 1        1.92      US  2024-11-21 19:49:59
# 2        6.03      GS  2024-11-21 19:50:30
# 3        6.26      US  2024-11-21 19:49:46
# 4        6.67      PN  2024-11-21 19:50:31

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             khorinsk  52.1657  109.7726    -10.12        98          99
# 1         san patricio  28.0170  -97.5169     22.97        15           0
# 2            grytviken -54.2811  -36.5092      6.86        74          74
# 3        haiku-pauwela  20.9219 -156.3051     24.03        76          75
# 4            adamstown -25.0660 -130.1015     22.95        89           7
#
#          Wind Speed Country                 Date
# City_ID
# 0              0.75      RU  2024-11-21 19:47:59
# 1              1.92      US  2024-11-21 19:49:59
# 2              6.03      GS  2024-11-21 19:50:30
# 3              6.26      US  2024-11-21 19:49:46
# 4              6.67      PN  2024-11-21 19:50:31

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(city_data_df["Lat"]).astype(float), pd.to_numeric(city_data_df["Max Temp"]).astype(float), facecolors="purple", edgecolors="black", alpha = 0.5)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Max Latitude vs Max Temperature ({today})")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(pd.to_numeric(city_data_df["Lat"]).astype(float), pd.to_numeric(city_data_df["Humidity"]).astype(float), facecolors="red", edgecolors="black", alpha = 0.5)


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(pd.to_numeric(city_data_df["Lat"]).astype(float), pd.to_numeric(city_data_df["Cloudiness"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(pd.to_numeric(city_data_df["Lat"]).astype(float), pd.to_numeric(city_data_df["Wind Speed"]).astype(float), facecolors="green", edgecolors="black", alpha = 0.5)


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             khorinsk  52.1657  109.7726    -10.12        98          99
# 1         san patricio  28.0170  -97.5169     22.97        15           0
# 3        haiku-pauwela  20.9219 -156.3051     24.03        76          75
# 5           mount airy  36.4993  -80.6073      9.49        44         100
# 6              fortuna  40.5982 -124.1573     14.40        99          75
#
#          Wind Speed Country                 Date
# City_ID
# 0              0.75      RU  2024-11-21 19:47:59
# 1              1.92      US  2024-11-21 19:49:59
# 3              6.26      US  2024-11-21 19:49:46
# 5              5.81      US  2024-11-21 19:52:27
# 6              2.06      US  2024-11-21 19:52:09

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        grytviken -54.2811  -36.5092      6.86        74          74
# 4        adamstown -25.0660 -130.1015     22.95        89           7
# 8           mungwi -10.1732   31.3694     19.49        80          67
# 9          huarmey -10.0681  -78.1522     21.40        75         100
# 12        waitangi -43.9535 -176.5597     12.12        91          47
#
#          Wind Speed Country                 Date
# City_ID
# 2              6.03      GS  2024-11-21 19:50:30
# 4              6.67      PN  2024-11-21 19:50:31
# 8              0.67      ZM  2024-11-21 19:47:47
# 9              4.59      PE  2024-11-21 19:51:35
# 12             3.58      NZ  2024-11-21 19:50:29

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(8,-20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Northern Hemisphere - Temp vs. Latitude Linear Regression Plot')

print(f"Regression line equation is: {line_eq}")
print(f"The r-value is: {rvalue}")
# Out:
# Regression line equation is: y = -0.67x + 33.88
# The r-value is: -0.8894377050099678

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Southern Hemisphere - Temp vs. Latitude Linear Regression Plot')

print(f"Regression line equation is: {line_eq}")
print(f"The r-value is: {rvalue}")
# Out:
# Regression line equation is: y = 0.27x + 28.62
# The r-value is: 0.663655504304529

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression Plot')

print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {rvalue}")


plt.show()
# Out:
# Regression line equation is: y = 0.34x + 59.37
# The r-squared is: 0.30211528257491355

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression Plot')

print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {rvalue}")


plt.show()
# Out:
# Regression line equation is: y = 0.34x + 78.18
# The r-squared is: 0.245282996021014

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression Plot')

print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {rvalue}")


plt.show()
# Out:
# Regression line equation is: y = 0.46x + 40.49
# The r-squared is: 0.2295082695633009

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness vs. Latitude Linear Regression Plot')

print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {rvalue}")


plt.show()
# Out:
# Regression line equation is: y = 0.39x + 71.74
# The r-squared is: 0.14768656445498704

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,14),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression Plot')

print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {rvalue}")


plt.show()
# Out:
# Regression line equation is: y = 0.03x + 2.82
# The r-squared is: 0.20464862561442732

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression Plot')

print(f"Regression line equation is: {line_eq}")
print(f"The r-squared is: {rvalue}")


plt.show()
# Out:
# Regression line equation is: y = -0.04x + 2.82
# The r-squared is: -0.2276245891269948

# %% [markdown]
# **Discussion about the linear relationship:**
# The data plots show:
#  - In general, as we move towards the equator (latitude 0), the maximum temperature rises. Likewise the max temperature drops as we move further away from the equator. The correlation is stronger for the northern hemisphere than the southern hemisphere and could warrant additional investigation.
#  - There are no strong correlations or apparent relationships to latitude vs humidity, latitude vs cloudiness, or latitude vs wind speed.
